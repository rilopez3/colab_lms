# %% [markdown]
# # GENERAL - INFORMACIÓN MUY IMPORTANTE
#
# No tienes que escribir **POR NINGÚN MOTIVO**.
#
# ```
# input()
# ```
#
# Siempre los inputs serán entregados con nombres dados en cada pregunta. Deberán dados usar los **NOMBRES USADOS POR PREGUNTA**
#
# Siempre escribir el código entre los comentarios:
#
#
#
# ```
#     ### --- INICIALIZAR CÓDIGO AQUÍ --- ###
#
#     ### --- FINALIZAR CÓDIGO AQUÍ --- ###
# ```

# %%
nombre = ''
correo_escuela_militar = ''

# %%
# DEBES EJECUTAR ESTA CELDA AL INICIAR
# NO MODIFICAR ESTA CELDA
import urllib.request
exec(urllib.request.urlopen('https://tinyurl.com/bde5v4cd').read())

# %% [markdown]
# # Instrucciones iniciales
#
#
#
# *   Para iniciar la solemne, lo primero que debes hacer es crear tu propia copia de esta página en tu Google Drive. Para ello, anda a "Archivo", y haz click en "Guardar una copia en Drive".
# *   Lo segundo que debes hacer, es ejecutar el trozo de código (llamado celda) que se encuentra a continuación. Para ello, si colocas el mouse encima de la celda, verás que aparece un signo de "Play". Al hacer click, estarás ejecutando la celda (el trozo de código).
# *   Para ejecutar el código que usas en cada pregunta, debes hacer exactamente lo mismo una vez hayas escrito tu código. Cuida con no editar la línea de código que se indica no editar.
# *   Al ejecutar el código de cada pregunta, tu código se evaluará con varios testcases que evaluarán que tu código funcione ante varios escenarios.
#
# *   Finalmente, cuando hayas finalizado tu prueba, deberás (1) descargar este archivo. Para ello, anda a "Archivo", haz click en "Descargar", y luego "Descargar .ipynb". El archivo que se descargue deberás subirlo en tu respuesta al formulario disponible en Canvas.

# %% [markdown]
# # 1. Área

# %% [markdown]
# ## Cómo llevar a cabo el desafío

# %% [markdown]
# En este ejercicio deberas escribir un programa que calcule el área de un círculo, dependiendo del string inicial, dado el radio.
#
# Nota: El área de un circulo se calcula de la forma $\pi * r^{2}$ (Considera $\pi$ = 3.14)
#
# `IMPORTANTE`: Debes redondear el resultado obtenido del calculo del área, por ejemplo si tienes "valor_obtenido = 31.4003", debes redondearlo a 31.4, para esto debes usar la funcion `round()`, de la siguiente forma:
# `round(valor_obtenido, 1)`, de esta forma redondeas a 1 decimal el resultado.

# %% [markdown]
# ## Aterrizando el ejercicio

# %% [markdown]
# ### **¿Cómo es el formato del input ? (Input Format)**
# Se entregará un número entero que representa el radio (`radio`) del círculo.
# ### **Nombres del input**
# La variable del input tendrá el siguiente nombre:
# **radio** = el valor del radio.
# ### **¿Qué puedo asumir sobre ese input? (Constraints)**
# None
# ### **¿Qué debo entregar? (Output Format)**
# ```
# "El área del circulo es {valor_obtenido}"
# ```
# donde {valor_obtenido} es un float.
# Recuerda usar "round(valor_obtenido, 1)".

# %% [markdown]
# ## Ejemplo

# %% [markdown]
# **Input Test Case 1:**
#
# ```
# 5      <- radio
# ```
#
# **Output Esperado:**
#
#
# ```
# El área del círculo es 78.5.
# ```
#
# **Explicación:**
#
# Usando la fórmula tenemos que el área se calcula como $\pi * 5^{2}$ lo que da como resultado 78.5.

# %%
def calculo_area(radio):
    ### --- INICIALIZAR CÓDIGO AQUÍ --- ###

    ### --- FINALIZAR CÓDIGO AQUÍ --- ###
    pass

# %%
# ESTA CELDA TE PERMITIRA TESTEAR TU CODIGO
# NO MODIFICAR ESTA CELDA
run_test('p1')

# %% [markdown]
# # 2. Área y Perímetro

# %% [markdown]
# ## Cómo llevar a cabo el desafío

# %% [markdown]
# En este ejercicio deberas escribir un programa que calcule el área o el perímetro de un círculo, dependiendo del string inicial, dado el radio.
#
# Nota: El perímetro de un circulo se calcula de la forma $2*\pi*r$ y el área se calcula de la forma $\pi * r^{2}$ (Considera $\pi$ = 3.14)
#
# `IMPORTANTE`: Debes redondear el resultado obtenido del calculo del área y del perímetro, por ejemplo si tienes "valor_obtenido = 31.4003", debes redondearlo a 31.4, para esto debes usar la funcion `round()`, de la siguiente forma:
# `round(valor_obtenido, 1)`, de esta forma redondeas a 1 decimal el resultado.

# %% [markdown]
# ## Aterrizando el ejercicio

# %% [markdown]
# ### **¿Cómo es el formato del input ? (Input Format)**
# Se entregará un string (`calculo`) indicando si se quiere el perímetro o el área, luego entregará un número entero que representa el radio (`radio`) del círculo.
# ### **Nombres del input**
# La variable de los inputs tendrán los siguientes nombres:
# **calculo** = el tipo de calculo que se realizara (area o perimetro) .
# **radio** = el valor del radio.
# ### **¿Qué puedo asumir sobre ese input? (Constraints)**
# el string inicial (calculo) siempre será `perimetro` o `area`
# ### **¿Qué debo entregar? (Output Format)**
# ```
# "El área del circulo es {valor_obtenido}" -> Si se pide área
# "El perímetro del círculo es {valor_obtenido}" -> Si se pide perimetro
# ```
# donde {valor_obtenido} es un float.
# Recuerda usar "round(valor_obtenido, 1)".

# %% [markdown]
# ## Ejemplo

# %% [markdown]
# **Input Test Case 1:**
#
# ```
# perimetro   <- calculo
# 5           <- radio
# ```
#
# **Output Esperado:**
#
#
# ```
# El perímetro del círculo es 31.4.
# ```
#
# **Explicación:**
#
# Usando la fórmula tenemos que el perímetro se calcula como $2 * \pi * r$ lo que da como resultado 31.4.
#
# **Input Test Case 2:**
#
# ```
# area   <- calculo
# 5      <- radio
# ```
#
# **Output Esperado:**
#
#
# ```
# El área del círculo es 78.5.
# ```
#
# **Explicación:**
#
# Usando la fórmula tenemos que el área se calcula como $\pi * 5^{2}$ lo que da como resultado 78.5.

# %%
def area_perimetro(calculo, radio):
    ### --- INICIALIZAR CÓDIGO AQUÍ --- ###

    ### --- FINALIZAR CÓDIGO AQUÍ --- ###
    pass

# %%
# ESTA CELDA TE PERMITIRA TESTEAR TU CODIGO
# NO MODIFICAR ESTA CELDA
run_test('p2')

# %% [markdown]
# # 3. Menor número

# %% [markdown]
# ## Cómo llevar a cabo el desafío

# %% [markdown]
# En este ejercicio, se te pide que crees un programa que encuentre el número más pequeño entre tres números dados como entrada.
#
# Tu objetivo es escribir un programa que compare los tres números y encuentre el valor mínimo entre ellos.
#
# Al final del programa, debes imprimir el número más pequeño encontrado.

# %% [markdown]
# ## Aterrizando el ejercicio

# %% [markdown]
# ### **¿Cómo es el formato del input ? (Input Format)**
# Tres números enteros que deberás comparar para encontrar el numero más pequeño.
# ### **Nombres del input**
# La variable de los inputs tendrán los siguientes nombres:
# **a** = primer número a entregar.
# **b** = segundo número a entregar.
# **c** = tercer número a entregar.
# ### **¿Qué puedo asumir sobre ese input? (Constraints)**
# Nunca habrá números iguales, seran los 3 distintos.
# ### **¿Qué debo entregar? (Output Format)**
# El menor número es {valor_obtenido}.

# %% [markdown]
# ## Ejemplo

# %% [markdown]
# **Input Test Case 1:**
#
# ```
# 20   <- a
# 30   <- b
# 10   <- c
# ```
#
# **Output Esperado:**
#
#
# ```
# El menor número es 10
# ```
#
# **Explicación:**
#
# 10 < 20 < 30, por lo tanto 10 es el menor de los tres números.

# %%
def menor_numero(a, b, c):
    ### --- INICIALIZAR CÓDIGO AQUÍ --- ###

    ### --- FINALIZAR CÓDIGO AQUÍ --- ###
    pass

# %%
# ESTA CELDA TE PERMITIRA TESTEAR TU CODIGO
# NO MODIFICAR ESTA CELDA
run_test('p3')

# %% [markdown]
# # 4. Temperatura

# %% [markdown]
# ## Cómo llevar a cabo el desafío

# %% [markdown]
# En este ejercicio deberas escribir un programa que recibirá un string indicando si se cambia de Celsius a Fahrenheit o viceversa y un número en celsius o fahrenheit según corresponda. Deberás devolver la conversión de la temperatura.
#
# Nota: La fórmula para la conversión es de la forma: $(°F - 32) * \frac{5}{9} = °C$

# %% [markdown]
# ## Aterrizando el ejercicio
#
# Se te dirá si se convierte de Celsius a Fahrenheit o viceversa, por ejemplo si el string inicial es `celsius` quiere decir que el número que vendrá es una temperatura en Celsius, por lo que debes tranformarlo a Fahrenheit. Lo mismo en caso de que el string inicial sea `fahrenheit` es porque debes convertirlo a Celsius.
# Una vez hecha la conversion debes imprimir un texto de la forma:
# ```
# "{°F} grados Fahrenheit equivalen a {°C} grados Celsius." -> En caso de que el string inicial sea 'fahrenheit'
# "{°C} grados Celsius equivalen a {°F} grados Fahrenheit." -> En caso contrario
# ```
# Donde debes reemplazar los { } con la temperatura dada y la obtenida respectivamente.

# %% [markdown]
# ### **¿Cómo es el formato del input ? (Input Format)**
# Se te entregará un string indicando el tipo de dato que se te dará, seguido de un float. El tipo de dato tendrá como nombre "`tipo`" y la temperatura (float) "`n`"
# ### **Nombres del input**
# La variable de los inputs tendrán los siguientes nombres:
# **tipo** = el tipo de temperatura que se entregará.
# **n** = el valor de la temperatura, por ejemplo 50.0
# ### **¿Qué puedo asumir sobre ese input? (Constraints)**
# El string (tipo) siempre será `celsius` o `fahrenheit`.
# ### **¿Qué debo entregar? (Output Format)**
# Un string con el resultado de la conversión de la temperatura según corresponda.
# Si es fahrenheit, el string será `{n} grados Fahrenheit equivalen a {valor_obtenido} grados Celsius.`
# Donde valor obtenido es el resultado de convertir la temperatura.

# %% [markdown]
# ## Ejemplo

# %% [markdown]
# **Input Test Case 1:**
#
# ```
# fahrenheit    <- tipo
# 50            <- n
# ```
#
# **Output Esperado:**
#
#
# ```
# 50 grados Fahrenheit equivalen a 10 grados Celsius.
# ```
#
# **Explicación:**
#
# Si reemplazamos 50 °F en la fórmula anteriormente entregada tendremos que:
# $(50 - 32) * \frac{5}{9} = °C$
# $(18) * \frac{5}{9} = °C$
# $\frac{90}{9} = °C$
# $10 = °C$
# Por lo tanto 50°F son 10°C
#
# **Input Test Case 2:**
#
# ```
# celsius       <- tipo
# 50            <- n
# ```
#
# **Output Esperado:**
#
#
# ```
# 50 grados Celsius equivalen a 122 grados Fahrenheit.
# ```
#
# **Explicación:**
#
# Si reemplazamos 50 °F en la fórmula anteriormente entregada tendremos que:
# $(F° - 32) * \frac{5}{9} = 50$
# $(F° - 32) * 5 = 450$
# $F° - 32 = 90$
# $F° = 122$
# Por lo tanto 50°C son 122°F

# %%
def temperatura(tipo, n):
    ### --- INICIALIZAR CÓDIGO AQUÍ --- ###

    ### --- FINALIZAR CÓDIGO AQUÍ --- ###
    pass

# %%
# ESTA CELDA TE PERMITIRA TESTEAR TU CODIGO
# NO MODIFICAR ESTA CELDA
run_test('p4')

# %% [markdown]
# # 5. Reloj Despertador

# %% [markdown]
# ## Cómo llevar a cabo el desafío

# %% [markdown]
# En este ejercicio deberas indicar la hora en cuando un reloj dará una alarma, pensando en que el reloj tiene una hora actual, pero solo puedes indicar los minutos en el futuro que sonará

# %% [markdown]
# ## Aterrizando el ejercicio

# %% [markdown]
# ### **¿Cómo es el formato del input ? (Input Format)**
# Recibaras tres números, el primero indicará la hora, y el segundo los minutos y el tercer los minutos a futuro.   Estos valores se llamaran **N** y  **M** y **T**.
# ### **¿Qué puedo asumir sobre ese input? (Constraints)**
# Puedes asumir que la hora será un valor entero que es estará entre 0 y 23 incluyendo dichos valores
# ### **¿Qué debo entregar? (Output Format)**
# Dos números, el primero indicando la hora y el segundo indicando los minutos

# %% [markdown]
# ## Ejemplo

# %% [markdown]
# **Input Test Case 1:**
#
# ```
# 10    <- N
# 1     <- M
# 50    <- T
# ```
#
# **Output Esperado:**
#
#
# ```
# La nueva hora es 10 con 51 minutos
# ```
#
# **Explicación:**
#
# Como son 50 minutos en el futuro, la hora se mantiene igual y solo se suma 50 con un 1 minuto quedando en 51.

# %%
def reloj(N, M, T):
    ### --- INICIALIZAR CÓDIGO AQUÍ --- ###

    ### --- FINALIZAR CÓDIGO AQUÍ --- ###
    pass

# %%
# ESTA CELDA TE PERMITIRA TESTEAR TU CODIGO
# NO MODIFICAR ESTA CELDA
run_test('p5')

# %% [markdown]
# # 6. Es par

# %% [markdown]
# ## Cómo llevar a cabo el desafío

# %% [markdown]
# En este ejercicio, te desafío a crear un programa que determine si un número dado es par o impar y además si es o no divisible por 3.
# Un número se considera par si se puede dividir exactamente por 2, es decir, si el residuo de la división entre el número y 2 es igual a 0.
#
# Nota: Para resolver este desafío, te recomiendo utilizar el operador de módulo (%), que devuelve el residuo de la división entre dos números. Si el residuo es 0, el número es par; de lo contrario, es impar.
#
# ¡Buena suerte!

# %% [markdown]
# ## Aterrizando el ejercicio

# %% [markdown]
# ### **¿Cómo es el formato del input ? (Input Format)**
# Un número entero (`n`)
# ### **Nombres del input**
# El valor o número entregado se llamará "**n**"
# ### **¿Qué puedo asumir sobre ese input? (Constraints)**
# Serán numeros mayores o iguales a 0.
# ### **¿Qué debo entregar? (Output Format)**
# ```
# "¡El número {valor_input} es par y es divisible por 3!" -> en caso de ser par y divisible por 3
# "¡El número {valor_input} es par!, pero no es divisible por 3" -> en caso de ser par pero no divisible por 3
# "El número {valor_input} no es par, pero es divisible por 3" -> en caso de ser impar y divisible por 3
# "El número {valor_input} no es par y tampoco es divisible por 3 :c" -> en caso de ser impar pero no divisible por 3
# ```

# %% [markdown]
# ## Ejemplo

# %% [markdown]
# **Input Test Case 1:**
#
# ```
# 40    <- n
# ```
#
# **Output Esperado:**
#
#
# ```
# ¡El número 40 es par!, pero no es divisible por 3
# ```
#
# **Explicación:**
#
# El resto obtenido de 40 % 2 es 0, lo que indica que 40 es par.
# Del mismo modo el resto obtenido de 40 % 3 es 1, como es distinto de 0, no es divisible por 3.
#
# **Input Test Case 2:**
#
# ```
# 30    <- n
# ```
#
# **Output Esperado:**
#
#
# ```
# ¡El número 30 es par y es divisible por 3!
# ```
#
# **Explicación:**
#
# El resto obtenido de 30 % 2 es 0, lo que indica que 30 es par.
# Del mismo modo el resto obtenido de 30 % 3 es 0, por lo tanto es divisible por 3.
#
# **Input Test Case 3:**
#
# ```
# 15    <- n
# ```
#
# **Output Esperado:**
#
#
# ```
# El número 15 no es par, pero es divisible por 3
# ```
#
# **Explicación:**
#
# El resto obtenido de 15 % 2 es 1, lo que indica que 15 no es par.
# Del mismo modo el resto obtenido de 15 % 3 es 0, por lo tanto si es divisible por 3.

# %%
def es_par(n):
    ### --- INICIALIZAR CÓDIGO AQUÍ --- ###

    ### --- FINALIZAR CÓDIGO AQUÍ --- ###
    pass

# %%
# ESTA CELDA TE PERMITIRA TESTEAR TU CODIGO
# NO MODIFICAR ESTA CELDA
run_test('p6')

# %% [markdown]
# # 7. División

# %% [markdown]
# ## Cómo llevar a cabo el desafío

# %% [markdown]
# En este ejercicio deberás escribir un programa que recibirá 2 números enteros, dividendo y divisior ($\frac{dividendo}{divisor}$), y deberás imprimir un string explicando la división, cual es su restultado y cual es el resto. En este caso no habrá decimales en el resultado, por esto es que se pide el resto de la división.
#
# Nota: Te sugerimos utilizar los operadores % y //. (Está mejor explicado en los ejemplos)
# A continuación un breve recordatorio:
#
# - El operador % aplica el módulo a un número, es decir, entrega el resto de la división.
# - El operador // aplica la parte entera a un número, es decir, entrega la parte entera de la división.

# %% [markdown]
# ## Aterrizando el ejercicio

# %% [markdown]
# ### **¿Cómo es el formato del input ? (Input Format)**
# Dos enteros llamados `dividendo`y `divisor` respectivamente.
# ### **¿Qué puedo asumir sobre ese input? (Constraints)**
# Nunca se entregará una division que no tenga sentido (como x número dividido 0).
# ### **¿Qué debo entregar? (Output Format)**
# Un string con el formato siguiente:
# `La división de {dividendo} entre {divisor} da como resultado {division entera usando //} y tiene como resto {resto obtenido usando %}`

# %% [markdown]
# ## Ejemplo

# %% [markdown]
# **Input Test Case 1:**
#
# ```
# 11    <- dividendo
# 5     <- divisor
# ```
#
# **Output Esperado:**
#
#
# ```
# La división de 11 entre 5 da como resultado 2 y tiene como resto 1
# ```
#
# **Explicación:**
#
# Si divides 11 y 5 usando // de la forma `11 // 5` da como resultado 2, mientras que si usas % de la forma `11 % 5` obtienes el resto 1.
# Para revisar que este correcto puedes multiplicar el resultado por el divisor y luego sumar el resto, lo que te deberia dar el dividendo, por ejemplo:
# ```
# {resultado} * {divisor} + {resto} = {dividendo}
# 2 * 5 + 1 = 11
# ```
# Lo que es correcto.

# %%
def division(dividendo, divisor):
    ### --- INICIALIZAR CÓDIGO AQUÍ --- ###

    ### --- FINALIZAR CÓDIGO AQUÍ --- ###
    pass

# %%
# ESTA CELDA TE PERMITIRA TESTEAR TU CODIGO
# NO MODIFICAR ESTA CELDA
run_test('p7')

# %% [markdown]
# # 8. Descomposición

# %% [markdown]
# ## Cómo llevar a cabo el desafío

# %% [markdown]
# En este ejercicio deberas debes generar un programa que descomponga un número en su cantidad de centenas, decenas y unidades.

# %% [markdown]
# ## Aterrizando el ejercicio

# %% [markdown]
# ### **¿Cómo es el formato del input ? (Input Format)**
# Recibirás un número entero mayor a a cero. Este valor se llamará **N**.
# ### **¿Qué puedo asumir sobre ese input? (Constraints)**
# Puedes asumir que será mayor a cero y menor a 999
# ### **¿Qué debo entregar? (Output Format)**
# El número de cada centena, decena y unidad

# %% [markdown]
# ## Ejemplo

# %% [markdown]
# **Input Test Case 1:**
#
# ```
# 301    <- N
# ```
#
# **Output Esperado:**
#
#
# ```
# El numero tiene
# 3 centenas
# 0 decenas
# 1 unidades
# ```
#
# **Explicación:**
#
# 3 * 100 + 0 * 10 + 1 * 1 = 301 que es valor que se indica

# %%
def descomposicion(N):
    ### --- INICIALIZAR CÓDIGO AQUÍ --- ###

    ### --- FINALIZAR CÓDIGO AQUÍ --- ###
    pass

# %%
# ESTA CELDA TE PERMITIRA TESTEAR TU CODIGO
# NO MODIFICAR ESTA CELDA
run_test('p8')

# %% [markdown]
# # 9. Número Palíndromo

# %% [markdown]
# ## Cómo llevar a cabo el desafío

# %% [markdown]
# Un número palindromo es un valor número que se puede leer de la misma forma de izquierda a derecha. Por ejemplo 5005 es un palíndromo, pero 123 no lo es.
# En este ejercicio deberas debes generar un programa que verifique si el número tiene cuatro dígitos y es palíndromo.

# %% [markdown]
# ## Aterrizando el ejercicio

# %% [markdown]
# ### **¿Cómo es el formato del input ? (Input Format)**
# Recibirás un número entero mayor a a cero. Este valor se llamará **N**.
# ### **¿Qué puedo asumir sobre ese input? (Constraints)**
# Puedes asumir que será mayor a cero y menor a 2147483647
# ### **¿Qué debo entregar? (Output Format)**
# Deberás entregar alguno de los siguientes siguientes tres opciones:
#
# Opción 1:
# ```
# El número ingresado no tiene cuatro dígitos.
# ```
# Opción 2:
# ```
# El número ingresado tiene cuatro dígitos, pero no es un palíndromo
# ```
# Opción 3:
# ```
# ¡ El número ingresado tiene cuatro dígitos, y si es un palíndromo !
# ```

# %% [markdown]
# ## Ejemplo

# %% [markdown]
# **Input Test Case 1:**
#
# ```
# 343    <- N
# ```
#
# **Output Esperado:**
#
#
# ```
# El número ingresado no tiene cuatro dígitos
# ```
#
# **Explicación:**
#
# Como no tiene cuatro digitos devuelve esa salida

# %%
def palindromo(N):
    ### --- INICIALIZAR CÓDIGO AQUÍ --- ###

    ### --- FINALIZAR CÓDIGO AQUÍ --- ###
    pass

# %%
# ESTA CELDA TE PERMITIRA TESTEAR TU CODIGO
# NO MODIFICAR ESTA CELDA
run_test('p9')

# %% [markdown]
# # 10. Cajero

# %% [markdown]
# ## Cómo llevar a cabo el desafío

# %% [markdown]
# En este ejercicio deberás entregar un programa que calcule la menor cantidad de billetes de \$20000, \$10000, \$5000, $2000 y \$1000 pesos chilenos necesarios. Para ello, recibirás el monto que un cliente del cajero automático desea retirar en efectivo.

# %% [markdown]
# ## Aterrizando el ejercicio

# %% [markdown]
# ### **¿Cómo es el formato del input ? (Input Format)**
# Un número positivo distinto de cero que representa la cantidad de dinero que el cliente quiere retirar. Este valor se llamará **N**.
# ### **¿Qué puedo asumir sobre ese input? (Constraints)**
# Puedes asumir que el cliente no entregará un valor que no pueda ser entregado en los billetes antes mencionado. Es decir, no tendrás valores tales como  \$1500 , \$1999 , etc.
# ### **¿Qué debo entregar? (Output Format)**
# El número de billetes de cada billete que entregará el cajero (si un billete no es utilizado deberá ser marcado como cero), junto con un string `de $<Billete>`  .

# %% [markdown]
# ## Ejemplo

# %% [markdown]
# **Input Test Case 1:**
#
# ```
# 23000    <- N
# ```
#
# **Output Esperado:**
#
#
# ```
# 1 de $20000
# 0 de $10000
# 0 de $5000
# 1 de $2000
# 1 de $1000
# ```
#
# **Explicación:**
#
# El cliente pide que \$23000. Uno podría entregar 23 billetes de \$1000 , pero eso **no sería la menor cantidad**, es por eso que se entrega un billete de \$20000 , uno de \$2000 y uno de \$1000

# %% [markdown]
# ### IMPORTANTE ESCRIBIR EL CÓDIGO ENTRE LOS COMENTARIOS INICIALIZAR CÓDIGO Y FINALIZAR CÓDIGO.

# %%
def cajero(N):
    ### --- INICIALIZAR CÓDIGO AQUÍ --- ###

    ### --- FINALIZAR CÓDIGO AQUÍ --- ###
    pass

# %%
# ESTA CELDA TE PERMITIRA TESTEAR TU CODIGO
# NO MODIFICAR ESTA CELDA
run_test('p10')
