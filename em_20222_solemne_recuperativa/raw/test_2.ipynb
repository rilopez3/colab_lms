# %% [markdown]
# # Solemne 2 ESM02IN 20222

# %% [markdown]
# ## Instrucciones iniciales
#
# - Para iniciar la solemne, lo primero que debes hacer es crear tu propia copia de esta página en tu Google Drive. Para ello, anda a "Archivo", y haz click en "Guardar una copia en Drive".
# - Lo segundo que debes hacer, es ejecutar el trozo de código (llamado celda) que se encuentra a continuación. Para ello, si colocas el mouse encima de la celda, verás que aparece un signo de "Play". Al hacer click, estarás ejecutando la celda (el trozo de código).
# - Para ejecutar el código que usas en cada pregunta, debes hacer exactamente lo mismo una vez hayas escrito tu código. Cuida con no editar la línea de código que se indica no editar.
# - Al ejecutar el código de cada pregunta, tu código se evaluará con varios testcases que evaluarán que tu código funcione ante varios escenarios.
# - Finalmente, cuando hayas finalizado tu prueba, deberás (1) descargar este archivo. Para ello, anda a "Archivo", haz click en "Descargar", y luego "Descargar .ipynb". El archivo que se descargue deberás subirlo en tu respuesta al formulario disponible en Canvas.

# %%
nombre = 'test2'
correo_escuela_militar = 'asd2@asd.cl'

# %%
# DEBES EJECUTAR ESTA CELDA AL INICIAR
# NO MODIFICAR ESTA CELDA
import urllib.request
exec(urllib.request.urlopen('https://tinyurl.com/3fhuennr').read())

# %% [markdown]
# # Enunciado
#
# Ha tocado desplegar tropas a lo largo de Chile, y te han dado el rol de generar un programa basado en funciones que permita asistir con este despliegue. Para ello, se ha pensado al país como una línea, que ha sido dividida en cierta cantidad de zonas.

# %% [markdown]
# 1. Es necesario crear la función `crear_tropas(zonas, cant_inicial)`, que deberá retornar una lista de largo `zonas` con `cant_inicial` de unidades en cada zona.
#
# Ejemplo input/output Case 1 Publico:
# ![image.png](data:image/png;base64,...)

# %%
def crear_tropas( zonas, cant_inicial ):
  tropas = []
  for i in range(zonas):
    tropas.append(cant_inicial)
  return tropas

# %%
# ESTA CELDA TE PERMITIRA TESTEAR TU CODIGO
# NO MODIFICAR ESTA CELDA
run_test('p1')

# %% [markdown]
# 2. Es necesario crear la función `agregar_unidades( tropas, zona, cant  )`, que deberá agregar la cantidad `cant` de unidades a la zona `zona` de las `tropas` (lista de enteros), y se debe retornar el listado de tropas actualizado.
#
# Ejemplo input/output Case 1 Publico:
# ![image.png](data:image/png;base64,...)

# %%
def agregar_unidades( tropas, zona, cant ):
  tropas[zona] += cant
  return tropas

# %%
# ESTA CELDA TE PERMITIRA TESTEAR TU CODIGO
# NO MODIFICAR ESTA CELDA
run_test('p2')

# %% [markdown]
# 3. Es necesario crear la función `mover_unidades( tropas, zona_origen, zona_destino, cant)`, que deberá reasignar una cantidad `cant` de unidades dentro de las `tropas`, que se moverán desde la zona `zona_origen` hacia la zona `zona_destino`. Deberá retornar el listado de tropas actualizado.
#
# Ejemplo input/output Case 1 Publico:![image.png](data:image/png;base64,...)

# %%
# ESTA CELDA TE PERMITIRA TESTEAR TU CODIGO
# NO MODIFICAR ESTA CELDA
run_test('p3')

# %% [markdown]
# 4. Es necesario crear la función `total_unidades(tropas)`. Esta función debe calcular la cantidad de unidades total que están asignadas en la lista `tropas`.
#
# Ejemplo input/output Case 1 Publico:![image.png](data:image/png;base64,...)

# %%
# ESTA CELDA TE PERMITIRA TESTEAR TU CODIGO
# NO MODIFICAR ESTA CELDA
run_test('p4')

# %% [markdown]
# 5. Como hay varias unidades que se han estado moviendo a lo largo del país, es necesario crear la función `reasignar_unidades(tropas)`. Esta función debe retornar la lista `tropas` reasignando las unidades de manera equitativa en todas las zonas, de tal forma que en todas las zonas exista la misma cantidad de unidades y la cantidad final de unidades no puede superar la cantidad inicial de unidades.
#
# Ejemplo input/output Case 1 Publico:
# ![image.png](data:image/png;base64,...)

# %%
# ESTA CELDA TE PERMITIRA TESTEAR TU CODIGO
# NO MODIFICAR ESTA CELDA
run_test('p5')
