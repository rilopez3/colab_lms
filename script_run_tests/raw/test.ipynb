# %% [markdown]
# # TEST 1

# %%
nombre = 'TEST1'
correo_escuela_militar = 'asd2@asd.cl'

# %%
# DEBES EJECUTAR ESTA CELDA AL INICIAR
# NO MODIFICAR ESTA CELDA
import urllib.request
# exec(urllib.request.urlopen('https://tinyurl.com/3fhuennr').read())
exec(open('../test_runner.py').read())

# %%
# <P1>
a = int(input())
b = int(input())
c = a + b
print(c)

# </P1>
# Out:
# 14

# %%
run_tests('T1', 'P1')
# Out:
# https://raw.githubusercontent.com/rilopez3/colab_lms/test/tests/T1/P1/1/input.txt
# TESTS CASES PASADOS: 0/0

# %%
# <P2>
a = int(input())
b = int(input())
c = a * b
print(c)
# </P2>
# Out:
# 42

# %%
run_tests('T1', 'P2')
# Out:
# TESTS CASES PASADOS: 0/0
